# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Chemco_Data.csv")
df.head()
# Out:
#     Period Country (Ship-to) Region (Ship-to) Product line (Material)  \
# 0  2019.01            Brazil    South America            Not assigned
# 1  2019.01            Brazil    South America            Not assigned
# 2  2019.01            Brazil    South America            Not assigned
# 3  2019.01            Brazil    South America            Not assigned
# 4  2019.01            Brazil    South America            Not assigned
#
#     Adjusted Weight KG  Distance (km)  CO2 (g/KmTO)     tkm  \
# 0               1965.6          121.0          38.0  237.51
# 1               7886.4            1.0          38.0    7.07
# 2               5257.6            1.0          38.0    4.71
# 3               5257.6            1.0          38.0    4.71
# 4               5257.6            1.0          38.0    4.71
#
#    Total CO2 (kg/KmTO)
# 0                 9.03
# 1                 0.27
# 2                 0.18
# 3                 0.18
# 4                 0.18

# %%
df.describe()
# Out:
#              Period   Adjusted Weight KG  Distance (km)  CO2 (g/KmTO)  \
# count  2.309500e+04         2.309500e+04   23095.000000       23095.0
# mean   2.019010e+03         1.829697e+04     490.586664          38.0
# std    6.503028e-11         2.168048e+04     625.099463           0.0
# min    2.019010e+03         1.100000e-01       1.000000          38.0
# 25%    2.019010e+03         6.000000e+03     112.000000          38.0
# 50%    2.019010e+03         1.700000e+04     279.000000          38.0
# 75%    2.019010e+03         2.490000e+04     608.500000          38.0
# max    2.019010e+03         1.628800e+06    8995.000000          38.0
#
#                  tkm  Total CO2 (kg/KmTO)
# count   23095.000000         23095.000000
# mean     6444.794762           244.902177
# std      9840.693180           373.946335
# min         0.000000             0.000000
# 25%      1128.900000            42.900000
# 50%      3247.470000           123.400000
# 75%      7915.120000           300.770000
# max    303738.910000         11542.080000

# %%
df.describe().T
# Out:
#                        count          mean           std      min      25%  \
# Period               23095.0   2019.010000  6.503028e-11  2019.01  2019.01
#  Adjusted Weight KG  23095.0  18296.970656  2.168048e+04     0.11  6000.00
# Distance (km)        23095.0    490.586664  6.250995e+02     1.00   112.00
# CO2 (g/KmTO)         23095.0     38.000000  0.000000e+00    38.00    38.00
# tkm                  23095.0   6444.794762  9.840693e+03     0.00  1128.90
# Total CO2 (kg/KmTO)  23095.0    244.902177  3.739463e+02     0.00    42.90
#
#                           50%       75%         max
# Period                2019.01   2019.01     2019.01
#  Adjusted Weight KG  17000.00  24900.00  1628800.00
# Distance (km)          279.00    608.50     8995.00
# CO2 (g/KmTO)            38.00     38.00       38.00
# tkm                   3247.47   7915.12   303738.91
# Total CO2 (kg/KmTO)    123.40    300.77    11542.08

# %%
df.isnull().sum()
# Out:
# Period                     0
# Country (Ship-to)          0
# Region (Ship-to)           0
# Product line (Material)    0
#  Adjusted Weight KG        0
# Distance (km)              0
# CO2 (g/KmTO)               0
# tkm                        0
# Total CO2 (kg/KmTO)        0
# dtype: int64

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000017757DA9248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017757E20C08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000017757E5A488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017757E8FE88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000017757EC9CC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000017757F01D88>]],
#       dtype=object)

# %%
pd.crosstab(df["Product line (Material)"],df["Country (Ship-to)"])
# Out:
# Country (Ship-to)               Argentina  Australia  Austria  Belgium  \
# Product line (Material)
# Biocides                                0          0        0        0
# Chloralkali                             0          0        0        0
# Chlorate + CLO2                         0          0        0        0
# Coagulants                              0          4        0       16
# Colorants                               0          0        0        0
# Defoamers                               0          0        0        0
# Dispersants/Scale&Corr. Inhib.          0          2        0        0
# Emulsifier/Demulsifiers                 0          0        0        0
# Felt conditioning & cleaners            0          0        0        0
# Inorganic salts and acids               0          0        0        0
# Microparticles                          0          8        0        0
# Monomers                                0          0        0        0
# Not assigned                            0          0        0        0
# Others                                  0          0        0        0
# Peroxygens                              0          0        0        0
# Polymers                               29          6        0        0
# Pulping Additives                       0          0        0        0
# SBH products                            0          0        0        0
# Services                                0          0        0        0
# Sizing                                  3         32      382        0
# Strength Additives                      0         15       15        0
# Sulphur products                        0          0        0        0
# Surface Additives                       0          0       41        0
# Tissue Additives                        0          0        0        0
#
# Country (Ship-to)               Brazil  Canada  Chile  China  Czech Republic  \
# Product line (Material)
# Biocides                             3      38      0     43               0
# Chloralkali                          0      55      0      0               0
# Chlorate + CLO2                     32       0      0      0               0
# Coagulants                           0     901      0      1             547
# Colorants                            1      39      0     13               0
# Defoamers                           10      95      0     20               3
# Dispersants/Scale&Corr. Inhib.      11      22      0     17               1
# Emulsifier/Demulsifiers              0       0      0      0               0
# Felt conditioning & cleaners         0      52      0     13               0
# Inorganic salts and acids            0       0      0      0               8
# Microparticles                      19      12      0     12               0
# Monomers                             2       0      0      0               0
# Not assigned                         8       4      0      9              19
# Others                               6       2      0      6               0
# Peroxygens                           0       0      0      0               0
# Polymers                           127     130      3    292              22
# Pulping Additives                    0       4      0      6               0
# SBH products                         0       0      0      4               0
# Services                             3       0      0      0               0
# Sizing                             129      66      5    145               0
# Strength Additives                  14      21      1     10               0
# Sulphur products                     0       0      0      0               0
# Surface Additives                    1       6      0      3               0
# Tissue Additives                     2       3      0      0               0
#
# Country (Ship-to)               Denmark  ...  South Korea  Spain  Sweden  \
# Product line (Material)                  ...
# Biocides                              0  ...            0     13      15
# Chloralkali                           0  ...            0      0      91
# Chlorate + CLO2                       0  ...            0      0       0
# Coagulants                          275  ...            0    576     746
# Colorants                             0  ...           70      3       2
# Defoamers                             2  ...            2      0      24
# Dispersants/Scale&Corr. Inhib.        0  ...            2      0       2
# Emulsifier/Demulsifiers               0  ...            0      0       0
# Felt conditioning & cleaners          0  ...           12      2       0
# Inorganic salts and acids             2  ...            0      0       3
# Microparticles                        0  ...           18      4      25
# Monomers                              0  ...            0      0       0
# Not assigned                          0  ...            2     17       0
# Others                                0  ...            0      0       0
# Peroxygens                            0  ...            2      5     176
# Polymers                             25  ...           41     93     155
# Pulping Additives                     0  ...            2      0       0
# SBH products                          0  ...            7      0       0
# Services                              0  ...            0      0       0
# Sizing                                0  ...           73     89      62
# Strength Additives                    0  ...           63     87      10
# Sulphur products                      0  ...            0      0     384
# Surface Additives                     0  ...           17      0       0
# Tissue Additives                      0  ...            3      6       0
#
# Country (Ship-to)               Taiwan  Thailand   USA  United Kingdom  \
# Product line (Material)
# Biocides                             0        10    77              17
# Chloralkali                          0         0   157               0
# Chlorate + CLO2                      0         0     0               1
# Coagulants                           1        27  4392             372
# Colorants                            4         3   298               4
# Defoamers                            5         3    88              31
# Dispersants/Scale&Corr. Inhib.       0         0    67              34
# Emulsifier/Demulsifiers              0         0     0               2
# Felt conditioning & cleaners         0         1    48               0
# Inorganic salts and acids            0         0     0               0
# Microparticles                      11        27   119               6
# Monomers                             0         0   164              32
# Not assigned                         1         0    65               0
# Others                               0         0     1               0
# Peroxygens                           0         0     0               0
# Polymers                             7        32   466             624
# Pulping Additives                    0         0    13               0
# SBH products                         0         0     0               0
# Services                             0         0     0               0
# Sizing                              13        64    75               4
# Strength Additives                  45        24   293               2
# Sulphur products                     0         0     0               0
# Surface Additives                    2         0    18               0
# Tissue Additives                     3         0     7               0
#
# Country (Ship-to)               Uruguay  Vietnam  Zambia
# Product line (Material)
# Biocides                              0        0       0
# Chloralkali                           0        0       0
# Chlorate + CLO2                     155        0       0
# Coagulants                            0        0       0
# Colorants                             0        0       0
# Defoamers                             0        0       0
# Dispersants/Scale&Corr. Inhib.        0        0       0
# Emulsifier/Demulsifiers               0        0       0
# Felt conditioning & cleaners          0        0       0
# Inorganic salts and acids             0        0       0
# Microparticles                        0        2       0
# Monomers                              0        0       0
# Not assigned                          0        0       0
# Others                                0        0       0
# Peroxygens                          158        0       0
# Polymers                              0        0       1
# Pulping Additives                     0        0       0
# SBH products                          0        0       0
# Services                              0        0       0
# Sizing                                0        1       0
# Strength Additives                    0        0       0
# Sulphur products                      0        0       0
# Surface Additives                     0        0       0
# Tissue Additives                      0        0       0
#
# [24 rows x 34 columns]

# %%
pd.pivot_table(df, index=["Product line (Material)","Region (Ship-to)"], aggfunc=len)
# Out:
#                                            Adjusted Weight KG  CO2 (g/KmTO)  \
# Product line (Material) Region (Ship-to)
# Biocides                Asia Pacific                     57.0          57.0
#                         EMEA                            399.0         399.0
#                         North America                   115.0         115.0
#                         South America                     3.0           3.0
# Chloralkali             EMEA                           1538.0        1538.0
# ...                                                       ...           ...
# Surface Additives       South America                     1.0           1.0
# Tissue Additives        Asia Pacific                      6.0           6.0
#                         EMEA                             30.0          30.0
#                         North America                    10.0          10.0
#                         South America                     2.0           2.0
#
#                                           Country (Ship-to)  Distance (km)  \
# Product line (Material) Region (Ship-to)
# Biocides                Asia Pacific                     57           57.0
#                         EMEA                            399          399.0
#                         North America                   115          115.0
#                         South America                     3            3.0
# Chloralkali             EMEA                           1538         1538.0
# ...                                                     ...            ...
# Surface Additives       South America                     1            1.0
# Tissue Additives        Asia Pacific                      6            6.0
#                         EMEA                             30           30.0
#                         North America                    10           10.0
#                         South America                     2            2.0
#
#                                           Period  Total CO2 (kg/KmTO)     tkm
# Product line (Material) Region (Ship-to)
# Biocides                Asia Pacific        57.0                 57.0    57.0
#                         EMEA               399.0                399.0   399.0
#                         North America      115.0                115.0   115.0
#                         South America        3.0                  3.0     3.0
# Chloralkali             EMEA              1538.0               1538.0  1538.0
# ...                                          ...                  ...     ...
# Surface Additives       South America        1.0                  1.0     1.0
# Tissue Additives        Asia Pacific         6.0                  6.0     6.0
#                         EMEA                30.0                 30.0    30.0
#                         North America       10.0                 10.0    10.0
#                         South America        2.0                  2.0     2.0
#
# [74 rows x 7 columns]

# %%
sns.pairplot(df)

# %%
corr=df.corr() 
cor
# Out:
#                            Period   Adjusted Weight KG  Distance (km)  \
# Period               1.000000e+00        -2.057339e-14  -1.806659e-14
#  Adjusted Weight KG -2.057339e-14         1.000000e+00  -1.867793e-01
# Distance (km)       -1.806659e-14        -1.867793e-01   1.000000e+00
# CO2 (g/KmTO)                  NaN                  NaN            NaN
# tkm                 -8.124243e-17         2.993483e-01   4.862213e-01
# Total CO2 (kg/KmTO) -2.518818e-15         2.993483e-01   4.862213e-01
#
#                      CO2 (g/KmTO)           tkm  Total CO2 (kg/KmTO)
# Period                        NaN -8.124243e-17        -2.518818e-15
#  Adjusted Weight KG           NaN  2.993483e-01         2.993483e-01
# Distance (km)                 NaN  4.862213e-01         4.862213e-01
# CO2 (g/KmTO)                  NaN           NaN                  NaN
# tkm                           NaN  1.000000e+00         1.000000e+00
# Total CO2 (kg/KmTO)           NaN  1.000000e+00         1.000000e+00

# %%
sns.heatmap(corr,annot=True)

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(corrmat, vmax=.8, square=True)
